# %% [markdown]
# <a href="https://colab.research.google.com/github/NihilisticMotif/Data-Science-Documentation/blob/main/Data-Science-Documentation/Mathematics/Calculus/Limit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **To Do Now:**
# * Finish this https://www.blackpenredpen.com/_files/ugd/287ba5_4c2b4ae62fe84ae894f8c80790e32a67.pdf

# %% [markdown]
# #Introduction of limit
#
# Reference:
# * https://youtu.be/HfACrKJ_Y2w

# %% [markdown]
# ###(1) Definition of Limit

# %% [markdown]
# **Limit meaning**
# * Limits = the value that a function (or sequence) approaches as the input (or index) approaches some value.
#
# **Limit Notation**
#
# * $\lim_{x \to c}f(x) = a$
#
# Output value of function $f(x)$ as input value $x$ approaches to value $c$ is equal to value $a$
#
# * $\lim_{x \to c^+}g(x) = a$
#
# Output value of function $g(x)$ as input value $x$ approaches to value $c$ is equal to value $a$ from right to left size of x axis.
#
# * $\lim_{x \to c^-}g(x) = b$
#
# Output value of function $g(x)$ as input value $x$ approaches to value $c$ is equal to value $b$ from left to right size of x axis.
#
# **Note**
#
# if $\lim_{x \to c^+}g(x) \neq \lim_{x \to c^-}g(x)$
# $\therefore \lim_{x \to c}g(x)$ is undefined.
#
# if $\lim_{x \to c^+}g(x) = \lim_{x \to c^-}g(x)$
# $\therefore \lim_{x \to c}g(x)$ is defined.

# %% [markdown]
# ![episondelta.png](data:image/png;base64,...)

# %% [markdown]
# **About this picture**
#
# Given that:
# * $\lim_{x\to x_0}f(x)=L$
# * $0<\delta<\lim_{x\to0}x$
# * $0<\epsilon<\lim_{x\to0}x$
#
# Function $f(x)$ is continuous if
# * $0<|x-x_0|<\delta\implies|f(x)-L|<\epsilon$
#
# Reference:
# * https://brilliant.org/wiki/epsilon-delta-definition-of-a-limit/

# %% [markdown]
# ###(2) Definition of Indeterminate Form

# %% [markdown]
# **What is indeterminate form?**
#
# * indeterminate = unknown value.
# * indeterminate form = a mathematical expression that have inconsistency value. (https://byjus.com/maths/indeterminate-forms/)
#
# **Types of indeterminate forms**
# * $\frac{c}{0}$
# * $\frac{0}{0}$
# * $\frac{\infty}{\infty}$
# * $0*\infty$
# * $1^\infty$
# * $\infty^0$
# * $0^0$
# * $\infty-\infty$
#
# **Note**
#
# $\frac{n}{\infty}$ is also indeterminate form because
# * $\frac{n}{\infty}=0\implies n=\infty*0$
# * $1=2=3=\infty*0$
#
# However for the sake of simplicity, in this lecture, $\frac{n}{\infty}=\lim_{x\to\infty}\frac{n}{x}=0$.
#
# Reference: https://math.stackexchange.com/questions/1372459/one-divided-by-infinity-is-not-zero

# %% [markdown]
# **Why is $\frac{c}{0}$ an indeterminate form?**
#
# This graph indicate that
# * $c\in\mathbb{R}$
# * $\lim_{x\to0^+}\frac{c}{x}=\infty$
# * $\lim_{x\to0^-}\frac{c}{x}=-\infty$
#
# $\therefore\lim_{x\to0}\frac{c}{x}$ is undefined.

# %% [markdown]
# ![Screen Shot 2023-05-05 at 3.06.03 PM.png](data:image/png;base64,...)

# %% [markdown]
# **Why is $\frac{0}{0}$ an indeterminate form?**
#
# Given that:
# * $a\in\mathbb{R}, 0a=0$
#
# $\therefore a=\frac{0}{0}$
#
# $\therefore 1=2=3=\frac{0}{0}$
#
# $\therefore\frac{0}{0}$ is undefined.
#
# reference: https://www.quora.com/Why-is-0-divided-by-0-undefined?no_redirect=1

# %% [markdown]
# **Why is $\frac{\infty}{\infty}$ an interminate form?**
#
# Given that:
# * $\lim_{x\to\infty}\frac{1}{x}=0$
#
# $\therefore\frac{1}{\infty}=0$
#
# $\frac{\infty}{\infty}=\frac{\frac{1}{\infty}}{\frac{1}{\infty}}=\frac{0}{0}$
#
# $\therefore\frac{\infty}{\infty}=\frac{0}{0}$

# %% [markdown]
# **Why is $0*\infty$ an interminate form?**
#
# Given that:
# * $\lim_{x\to\infty}\frac{1}{x}=0$
# * $\frac{1}{\infty}=0$
#
# $\therefore0*\infty=\frac{\infty}{\infty}=\frac{0}{0}$

# %% [markdown]
# **Why is $1^\infty$ an interminate form?**
#
# Given that:
# * $a^b=c\implies \log_a(c)=b \implies a^{\log_a(c)}=c$
#
# $\therefore 1^{\infty}=a^{\log_a(1^{\infty})}$
#
# According to logarithm: $\log_a(x^y)=y*\log_a(x)=\log_a(x)*y$
#
# $1^{\infty}=a^{{\infty}*\log_a(1)}$
#
# According to logarithm: $\log_a(1)=0$
#
# $1^{\infty}=a^{{\infty}*0}$
#
# According to limit: ${\infty}*0$ is interminate forms
#
# $\therefore 1^{\infty}$ is undifined
#
# **Fun Fact**
#
# * $\lim_{n\to\infty}(1+\frac{c}{n})^n=e^c$
# * $\lim_{n\to\infty}1^n=1$
#
# * $\therefore$ There is no universal value for $1^{\infty}$.
#
# Reference: https://math.stackexchange.com/questions/714170/what-is-infinity-to-the-power-zero

# %% [markdown]
# **Why is $\infty^0$ an interminate form?**
#
# $\infty^0=c^{0*\log_c(\infty)}=c^{0*\infty}$
#
# According to limit: ${\infty}*0$ is interminate forms
#
# $\therefore\infty^0$ is undefined
#
# Reference:
# * https://qr.ae/pyI7Gk
# * https://math.stackexchange.com/questions/714170/what-is-infinity-to-the-power-zero

# %% [markdown]
# **Why is $0^0$ an interminate form?**
#
# Given that: $\lim_{n\to\infty}\frac{1}{n}=0$
#
# $\therefore 0^0=(\frac{1}{\infty})^{\frac{1}{\infty}}$
#
# $0^0=\infty^{\frac{-1}{\infty}}$
#
# $0^0=\infty^{0}$
#
# According to limit: $\infty^{0}$ is an interminate form
#
# $\therefore 0^0$ is undefined.

# %% [markdown]
# **Why is $\infty-\infty$ an interminate form?**
#
# **Answer No.1**
#
# $\lim_{x\to\infty}x+c=\infty$
#
# $\therefore\infty-\infty=a-b$
#
# The value of $a$ and $b$ are not defined.
#
# $\therefore\infty-\infty$ is undefined.
#
# **Answer No.2**
#
# According to Riemann Series Theorem: If series that:
# * $\sum_{i=0}^{\infty}s(x_i)$ is a sum of $\sum_{i=0}^{\infty}f(x_i)$ and $\sum_{i=0}^{\infty}g(x_i)$
# * $\sum_{i=0}^{\infty} f(x_i)=\infty$
# * $\sum_{i=0}^{\infty} g(x_i)=-\infty$
#
# Then by a suitable rearrangement of terms, a series may be made to converge to any desired value, or to diverge. In other words, different order of sequence in this infinite series result in different value.
#
# $\infty-\infty$ is undefined because the sequence of the series is not defined.
#
# Reference:
# * https://qr.ae/pyp0iL
# * https://youtu.be/-EtHF5ND3_s
# * https://mathworld.wolfram.com/RiemannSeriesTheorem.html

# %% [markdown]
# ###(3) Limit Rules, $+,-,x,\div$ of ($\lim \neq \infty$)

# %% [markdown]
# Suppose
# * $c$ is a constant
# * $\lim_{x \to a}f(x) \neq \infty $
# * $\lim_{x \to a}g(x) \neq \infty$
# * $\lim_{x \to a}f(x) = F$
# * $\lim_{x \to a}g(x) = G$
#
# 1. Multiply by Constant (Constant Property)
#
# $\lim_{x \to a}[f(x)*c] = c*\lim_{x \to a}f(x) = c*F$
#
# 2. Sum and Difference Property
#
# $\lim_{x \to a}[f(x)\pm g(x)] = \lim_{x \to a}f(x) \pm \lim_{x \to a}g(x) = F\pm G$
#
# 3. Multiplication (Product Property)
#
# $\lim_{x \to a}[f(x)*g(x)] = \lim_{x \to a}f(x)*\lim_{x \to a}g(x)=F*G$
#
# 4. Division
#
# $\lim_{x \to a}[\frac{f(x)}{g(x)}] = \frac{\lim_{x \to a}f(x)}{\lim_{x \to a}g(x)} = \frac{F}{G}$ for $G \neq 0$
#
# 5. Power by Constant
#
# $\lim_{x \to a}[f(x)]^c = (\lim_{x \to a}f(x))^c = F^c$

# %% [markdown]
# ###(4) Limit and Continuity

# %% [markdown]
# $f(x)$  is said to be continuous at $x=a$ if
# 1. $\lim_{x \to a}f(x) = f(a)$
# 2. $\lim_{x \to a}f(x)$ and $f(a)$ are exist.

# %% [markdown]
# $f(x)$  is said to be continuous on the interval $(b,c)$ if $f(x)$  is said to be continuous at $x=a$ for every $a$ in $(b,c)$
#
# $f(x)$  is said to be continuous on the interval $[b,c]$ if $f(x)$  is said to be continuous at $x=a$ for every $a$ in $[b,c]$

# %% [markdown]
# Type of Discontinuity
# 1. Jump Discontinuity
# 2. Removeable Discontinuity
# 3. Infinite Discontinuity
# 4. Wild Discontinuity

# %%
# importing the required module
import matplotlib.pyplot as plt
import numpy as np
import math
from pylab import *

x=linspace(0,1,100)    
y=zeros(100)
y[x<0.5] = x[x<0.5]
y[x>=0.5] = 1 + x[x>=0.5]

pos = np.where(np.abs(np.diff(y)) >= 0.5)[0]+1
x = np.insert(x, pos, np.nan)
y = np.insert(y, pos, np.nan)

plot(x, y)

plt.title('''Jump Discontinuity
$f(x)${${g(x):x<0.5}$, ${h(x):x \geq 0.5}$}''')
plt.grid()
# function to show the plot
plt.show()

# %%
# importing the required module
import matplotlib.pyplot as plt
import numpy as np
import math
from pylab import *

x=linspace(-5,7,1000)    
y=(pow(x-3,2)*(x-4))/(x-4)

plot(x, y)

plt.title('''Removeable Discontinuity
$f(x)= \\frac{(x-3)^2*(x-4)}{(x-4)}$''')
plt.grid()
# function to show the plot
plt.show()

# %%
# importing the required module
import matplotlib.pyplot as plt
import numpy as np
import math
from pylab import *

x=linspace(-10,10,1000)    
y=1/(x-2)

plot(x, y)

plt.title('''Infinite Discontinuity
$f(x)=\\frac{1}{x-2}$''')
plt.grid()
# function to show the plot
plt.show()

# %%
# importing the required module
import matplotlib.pyplot as plt
import numpy as np
import math
from pylab import *

x=linspace(-5,5,1000)    
y=np.cos(1/x)

plot(x, y)

plt.title('''Wild Discontinuity
$f(x)=\\cos(\\frac{1}{x})$''')
plt.grid()
# function to show the plot
plt.show()

# %% [markdown]
# ###(5) The Squeeze Theorem, $h(x) \leq g(x) \leq f(x)$ and $\lim_{x \to a}h(x) = \lim_{x \to a}f(x) = L$ then $\lim_{x \to a}g(x) =L$

# %% [markdown]
# $h(x) \leq g(x) \leq f(x)$ when $x$ is nearly $a$ and $\lim_{x \to a}h(x) = \lim_{x \to a}f(x) = L$ then $\lim_{x \to a}g(x) =L$

# %% [markdown]
# Example 1:
#
# $h(x) = -x^2$ (blue line in Graph No.1)
#
# $g(x) = g(x) $ (green line in Graph No.1)
#
# $f(x) = x^2$ (red line in Graph No.1)
#
# $\lim_{x \to 0}h(x) = \lim_{x \to 0}f(x) = 0$
#
# $\therefore \lim_{x \to 0}g(x)=0$

# %%
# importing the required module
import matplotlib.pyplot as plt
import numpy as np
import math
x = np.linspace(-10,10,1000)


# corresponding y axis values
y1 = np.power(x,2)
y2 = np.power(x,2)*np.sin(1/x)
y3 = -np.power(x,2)
# plotting the points 
plt.plot(x, y1,'r')
plt.plot(x, y2,'g')
plt.plot(x, y3,'b')
  
# naming the x axis
plt.xlabel('x - axis')
# naming the y axis
plt.ylabel('y - axis')
  
# giving a title to my graph
plt.title('Graph No.1')
plt.grid()
# function to show the plot
plt.show()

# %% [markdown]
# Example 2:
#
# $\lim_{x \to 0}x^2\sin(\frac{1}{x}) = ?$
#
# $\lim_{x \to 0}x^2\sin(\frac{1}{x}) = \lim_{x \to 0}x^2 * \lim_{x \to 0}\sin(\frac{1}{x})$
#
# $-1 \leq \sin(\frac{1}{x}) \leq 1$
#
# $-x^2 \leq x^2\sin(\frac{1}{x}) \leq x^2$
#
# $\lim_{x \to 0}-x^2 = \lim_{x \to 0}x^2 = 0$
#
# $\therefore \lim_{x \to 0}x^2\sin(\frac{1}{x}) = 0$

# %% [markdown]
# ###(6) Common way to solve Limit

# %% [markdown]
# ![KhanLimit.png](data:image/png;base64,...)

# %% [markdown]
# Reference: https://www.khanacademy.org/math/ap-calculus-ab/ab-limits-new/ab-1-7/a/limit-strategies-flow-chart

# %% [markdown]
# **How to solve limit with $\frac{n}{0}$ form?**
#
# Given that:
# * $g(a)+b=0$
# * $\lim_{x\to a}\frac{f(x)+c}{g(x)+b}=\frac{f(x)+c}{0}$
#
# Transform $\lim_{x\to a}\frac{f(x)+c}{g(x)+b}$ in to
# * [Factoring]: $\lim_{x\to a}\frac{h(x)k(x)}{h(x)}=\lim_{x\to a}\frac{h(x)}{h(x)k(x)^{-1}}=k(a)$
# * [Conjugate]: $\lim_{x\to a}\frac{k(x)}{p(x)}=\frac{k(a)}{p(a)}$
# * [Use Trigonometry Identity]
# * [Approximate]
# * Try to avoid Indeterminate Form

# %% [markdown]
# **How to solve limit with $\lim_{x\to\infty}\frac{f(x)}{g(x)}$ form?**
#
# If:
# * $f(x)=\sum_{i=m_0}^ma_ix^i$
# * $g(x)=\sum_{i=n_0}^nb_ix^i$
# * $\implies\lim_{x\to\infty}\frac{f(x)}{g(x)}=\frac{a_mx^m}{b_nx^n}=\frac{a_m}{b_n}x^{m-n}$

# %% [markdown]
# **How to solve limit with $\infty-\infty$ form?**
#
# Given that:
# * $\lim_{x\to a}f(x)=\infty$
# * $\lim_{x\to a}g(x)=\infty$
#
# Transform $\lim_{x\to a}f(x)-g(x)$ in to
# * $\lim_{x\to a}\frac{(f(x)-g(x))(f(x)+g(x))}{f(x)+g(x)}$

# %% [markdown]
# ###(7) L'Hôpital's rule

# %% [markdown]
# **What is L'Hôpital's rule**
#
# Given that:
# * $\lim_{x\to a}\frac{f(x)}{g(x)}=\frac{0}{0}$ or
# * $\lim_{x\to a}\frac{f(x)}{g(x)}=\frac{\infty}{\infty}$
# * $\implies \lim_{x\to a}\frac{f(x)}{g(x)}=\lim_{x\to a}\frac{f'(x)}{g'(x)}$
#
# Reference: https://tutorial.math.lamar.edu/classes/calci/lhospitalsrule.aspx

# %% [markdown]
# #[Unfinished] Exercise by blackpenredpen (https://youtu.be/TglD4Y6lmQk)

# %% [markdown]
# ###[1] [Limits From Piecewise Functions]

# %% [markdown]
# **(Q11)**
#
# $\lim_{x\to-2}f(x)\{x\neq -2\implies f=3x+1,x=-2\implies f=2\}$
#
# $\lim_{x\to-2}f(x)=3*(-2)+1=-6+1=-5$

# %% [markdown]
# **(Q12)**
#
# $\lim_{x\to c}\frac{1}{(x-c)^2}=\frac{1}{x^2-2xc+c^2}=\frac{1}{x^2-2x^2+x^2}=\infty$

# %% [markdown]
# ###[2] [Limit As x→a. Do NOT use L’Hospital’s Rule]

# %% [markdown]
# **How to solve limit with $\frac{n}{0}$ form?**
#
# Given that:
# * $g(a)+b=0$
# * $\lim_{x\to a}\frac{f(x)+c}{g(x)+b}=\frac{f(x)+c}{0}$
#
# Transform $\lim_{x\to a}\frac{f(x)+c}{g(x)+b}$ in to
# * $\lim_{x\to a}\frac{h(x)k(x)}{h(x)}=\lim_{x\to a}\frac{h(x)}{h(x)k(x)^{-1}}=k(a)$
# * $\lim_{x\to a}\frac{k(x)}{h(x)}=\frac{k(a)}{h(a)}$
# * Try to avoid Indeterminate Form

# %% [markdown]
# **(Q21)**
#
# $\lim_{x\to8}\frac{(x^2-7x-8)}{x-8}=\frac{(x+1)(x-8)}{x-8}=x+1=8+1=9$

# %% [markdown]
# **(Q23)**
#
# $\lim_{x\to4}\frac{(x+5)^{\frac{1}{2}}-3}{x-4}=\frac{((x+5)^{\frac{1}{2}}-3)((x+5)^{\frac{1}{2}}+3)}{(x-4)((x+5)^{\frac{1}{2}}+3)}$
#
# $\lim_{x\to4}\frac{(x+5)^{\frac{1}{2}}-3}{x-4}=\frac{x+5-9}{(x-4)((x+5)^{\frac{1}{2}}+3)}$
#
# $\lim_{x\to4}\frac{(x+5)^{\frac{1}{2}}-3}{x-4}=\frac{x-4}{(x-4)((x+5)^{\frac{1}{2}}+3)}$
#
# $\lim_{x\to4}\frac{(x+5)^{\frac{1}{2}}-3}{x-4}=\frac{1}{((x+5)^{\frac{1}{2}}+3)}$
#
# $\lim_{x\to4}\frac{(x+5)^{\frac{1}{2}}-3}{x-4}=\frac{1}{((4+5)^{\frac{1}{2}}+3)}$
#
# $\lim_{x\to4}\frac{(x+5)^{\frac{1}{2}}-3}{x-4}=\frac{1}{9^{\frac{1}{2}}+3}$
#
# $\lim_{x\to4}\frac{(x+5)^{\frac{1}{2}}-3}{x-4}=\frac{1}{3+3}$
#
# $\lim_{x\to4}\frac{(x+5)^{\frac{1}{2}}-3}{x-4}=\frac{1}{6}$
#
#
# reference: https://math.stackexchange.com/questions/1353339/calculus-solving-limits-with-square-roots

# %% [markdown]
# **(Q24)**
#
# $\lim_{x\to2}\frac{x^2-2x}{(x+2)^{\frac{1}{2}}-2}=\frac{x(x-2)((x+2)^{\frac{1}{2}}+2)}{((x+2)^{\frac{1}{2}}-2)((x+2)^{\frac{1}{2}}+2)}$
#
# $\lim_{x\to2}\frac{x^2-2x}{(x+2)^{\frac{1}{2}}-2}=\frac{x(x-2)((x+2)^{\frac{1}{2}}+2)}{x+2-4}$
#
# $\lim_{x\to2}\frac{x^2-2x}{(x+2)^{\frac{1}{2}}-2}=\frac{x(x-2)((x+2)^{\frac{1}{2}}+2)}{x-2}$
#
# $\lim_{x\to2}\frac{x^2-2x}{(x+2)^{\frac{1}{2}}-2}=x((x+2)^{\frac{1}{2}}+2)$
#
# $\lim_{x\to2}\frac{x^2-2x}{(x+2)^{\frac{1}{2}}-2}=2((2+2)^{\frac{1}{2}}+2)$
#
# $\lim_{x\to2}\frac{x^2-2x}{(x+2)^{\frac{1}{2}}-2}=8$

# %% [markdown]
# **(Q25)**
#
# $\lim_{x\to0}\frac{(1+x)^2-1}{(1+x)^3-1}=\frac{1+2x+x^2-1}{(1+2x+x^2)(1+x)-1}$
#
# $\lim_{x\to0}\frac{(1+x)^2-1}{(1+x)^3-1}=\frac{2x+x^2}{1+2x+x^2+x+2x^2+x^3-1}$
#
# $\lim_{x\to0}\frac{(1+x)^2-1}{(1+x)^3-1}=\frac{x(2+x)}{2x+x^2+x+2x^2+x^3}$
#
# $\lim_{x\to0}\frac{(1+x)^2-1}{(1+x)^3-1}=\frac{(2+x)}{2+x+1+2x+x^2}$
#
# $\lim_{x\to0}\frac{(1+x)^2-1}{(1+x)^3-1}=\frac{(2+0)}{2+0+1+0+0}$
#
# $\lim_{x\to0}\frac{(1+x)^2-1}{(1+x)^3-1}=\frac{2}{3}$

# %% [markdown]
# ###[3] [Limit as $x\to\infty$]

# %% [markdown]
# **How to solve limit with $\lim_{x\to\infty}\frac{f(x)}{g(x)}$ form?**
#
# If:
# * $f(x)=\sum_{i=0}^ma_ix^i$
# * $g(x)=\sum_{i=0}^nb_ix^i$
# * $\implies\lim_{x\to\infty}\frac{f(x)}{g(x)}=\frac{a_mx^m}{b_nx^n}=\frac{a_m}{b_n}x^{m-n}$

# %% [markdown]
# **How to solve limit with $\infty-\infty$ form?**
#
# Given that:
# * $\lim_{x\to a}f(x)=\infty$
# * $\lim_{x\to a}g(x)=\infty$
#
# Transform $\lim_{x\to a}f(x)-g(x)$ in to
# * $\lim_{x\to a}\frac{(f(x)-g(x))(f(x)+g(x))}{f(x)+g(x)}$

# %% [markdown]
# **(Q36)**
#
# $\lim_{x\to\infty}\cos(\tan^{-1}(x))=\cos(\frac{\pi}{2})=0$

# %% [markdown]
# **(Q38)**
#
# $\lim_{x\to\infty}\frac{2x^2-5x-3}{x^2-2x-3}=\frac{(2x+1)(x-3)}{(x-3)(x+1)}$
#
# $\lim_{x\to\infty}\frac{2x^2-5x-3}{x^2-2x-3}=\frac{2x+1}{x+1}$
#
# $\lim_{x\to\infty}\frac{2x^2-5x-3}{x^2-2x-3}=\frac{2x}{x}$
#
# $\lim_{x\to\infty}\frac{2x^2-5x-3}{x^2-2x-3}=2$

# %% [markdown]
# **(Q43) (This solution is wrong! because $\lim_{x\to\infty}x-x\in\{\text{Indeterminate Form}\}$)**
#
# $\lim_{x\to\infty}(x+3)^{\frac{1}{2}}-(x-1)^{\frac{1}{2}}=(x)^{\frac{1}{2}}-(x)^{\frac{1}{2}}=0$

# %% [markdown]
# **(Q43) (correct solution)**
#
# $\lim_{x\to\infty}(x+3)^{\frac{1}{2}}-(x-1)^{\frac{1}{2}}=\lim_{x\to\infty}\frac{(x+3)^{\frac{1}{2}}-(x-1)^{\frac{1}{2}}}{1}*\frac{(x+3)^{\frac{1}{2}}+(x-1)^{\frac{1}{2}}}{(x+3)^{\frac{1}{2}}+(x-1)^{\frac{1}{2}}}$
#
# $\lim_{x\to\infty}(x+3)^{\frac{1}{2}}-(x-1)^{\frac{1}{2}}=\lim_{x\to\infty}\frac{x+3-x+1}{(x+3)^{\frac{1}{2}}+(x-1)^{\frac{1}{2}}}$
#
# $\lim_{x\to\infty}(x+3)^{\frac{1}{2}}-(x-1)^{\frac{1}{2}}=\lim_{x\to\infty}\frac{4}{(x+3)^{\frac{1}{2}}+(x-1)^{\frac{1}{2}}}$
#
# $\lim_{x\to\infty}(x+3)^{\frac{1}{2}}-(x-1)^{\frac{1}{2}}=\lim_{x\to\infty}\frac{4}{\infty}=0$

# %% [markdown]
# **Solve $\lim_{x\to\infty}e^{10x}-4e^{6x}+3e^{x}+2e^{-2x}-9e^{-15x}$**
#
# $\lim_{x\to\infty}e^{10x}-4e^{6x}+3e^{x}+2e^{-2x}-9e^{-15x}=e^{10x}(1-4e^{-4x}+3e^{-9x}+2e^{-12x}-9e^{-25x})$
#
# $\lim_{x\to\infty}e^{10x}-4e^{6x}+3e^{x}+2e^{-2x}-9e^{-15x}=e^{10x}(1-0+0+0-0)$
#
# $\lim_{x\to\infty}e^{10x}-4e^{6x}+3e^{x}+2e^{-2x}-9e^{-15x}=\infty$
#
#
# Reference: https://tutorial.math.lamar.edu/classes/calci/LimitsAtInfinityII.aspx

# %% [markdown]
# **Solve $\lim_{x\to-\infty}e^{10x}-4e^{6x}+3e^{x}+2e^{-2x}-9e^{-15x}$**
#
# $\lim_{x\to-\infty}e^{10x}-4e^{6x}+3e^{x}+2e^{-2x}-9e^{-15x}=9e^{-15x}(\frac{e^{25x}}{9}-\frac{4e^{11x}}{9}+\frac{3e^{6x}}{9}+\frac{2e^{3x}}{9}-1)$
#
# $\lim_{x\to-\infty}e^{10x}-4e^{6x}+3e^{x}+2e^{-2x}-9e^{-15x}=9e^{-15x}(0-0+0+0 -1)$
#
# $\lim_{x\to-\infty}e^{10x}-4e^{6x}+3e^{x}+2e^{-2x}-9e^{-15x}=\infty(0-0+0+0 -1)$
#
# $\lim_{x\to-\infty}e^{10x}-4e^{6x}+3e^{x}+2e^{-2x}-9e^{-15x}=-\infty$
#
# Reference: https://tutorial.math.lamar.edu/classes/calci/LimitsAtInfinityII.aspx

# %% [markdown]
# **(Q42)**
#
# $\lim_{x\to\infty}(2^x+3^x)^{\frac{1}{x}}=(3^x)^{\frac{1}{x}}=3$

# %% [markdown]
# ###[4] [L’Hospital’s Rule]
