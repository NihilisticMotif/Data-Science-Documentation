# %% [markdown]
# ###1: Michael Penn: $(x+y)^n=x^n+y^n$

# %% [markdown]
# **Question:**
#
# $(x+y)^n=x^n+y^n$
#
# * $x,y\in\mathbb{R}$
# * $y\neq0$
# * $y=?$

# %% [markdown]
# ![04:01:2023,(x+y)^n=x^n+y^n.png](data:image/png;base64,...)

# %% [markdown]
# **Answer:**
#
# if $n\in\mathbb{Z}$
#
# 1. if $y=0\implies(x+0)^n=x^n+0^n=x^n$
# 2. if $y=-x\implies (x-x)^n=0=x^n-x^n, n=2m$

# %% [markdown]
# **Answer:**
#
# if $n\in\mathbb{Z}$
#
# 1. if $y=0\implies(x+0)^n=x^n+0^n=x^n$
#
# 2. if $n=1,y\neq0$
#
# $x+y=x+y$
#
# $x-x=y-y$
#
# $\therefore x,y\in\mathbb{R},y\neq0$
#
# 3. if $n=2,y\neq0$
#
# $(x+y)^2=x^2+y^2$
#
# $x^2+2xy+y^2=x^2+y^2$
#
# $2xy=0$
#
# if $x\neq0$ and $y\neq0\implies y\in\{\}$
#
# if $x=0$ and $y\neq0\implies y\in\mathbb{R}$
#
# 4. if $n>2,y\neq0$
#
# * 4.1: if $m\in\mathbb{Z},n=2m,y=-x$
#
# $\therefore (x-x)^{2m}\neq x^{2m}+(-x)^{2m}=2x^{2m}$
#
# * 4.2: if $m\in\mathbb{Z},n=2m+1,y=-x$
#
# $\therefore (x-x)^{2m+1} = x^{2m+1}+(-x)^{2m+1}=0$
#
# **The Final Answer**
#
# $\therefore y=\{-x,0\}$
#
# * $x\in\mathbb{R}$
# * $m,n\in\mathbb{Z}$
# * $n\geq3,n=2m+1$

# %% [markdown]
# **unfinished**
#
# **Answer:**
#
# if $n\in\mathbb{Z}$
#
# 1. if $y=0\implies(x+0)^n=x^n+0^n=x^n$
#
# 2. if $n=1,y\neq0$
#
# $x+y=x+y$
#
# $x-x=y-y$
#
# $\therefore x,y\in\mathbb{R},y\neq0$
#
# 3. if $n=2,y\neq0$
#
# $(x+y)^2=x^2+y^2$
#
# $x^2+2xy+y^2=x^2+y^2$
#
# $2xy=0$
#
# if $x\neq0$ and $y\neq0\implies y\in\{\}$
#
# if $x=0$ and $y\neq0\implies y\in\mathbb{R}$
#
# 4. if $n>2,y\neq0$
#
# According to Binomial theorem: $(x+y)^n=\Sigma_{r=0}^n\frac{n!}{(n-r)!*r!}x^{n-r}y^r$
#
# $(x+y)^n=\frac{n!}{(n-0)!*0!}x^{n-0}y^0+\frac{n!}{(n-1)!*1!}x^{n-1}y^1+...+\frac{n!}{(n-(n-1))!*(n-1)!}x^{n-(n-1)}y^{n-1}+\frac{n!}{(n-n)!*n!}x^{n-n}y^n$
#
# $(x+y)^n=x^n+nx^{n-1}y+...+nxy^{n-1}+y^n$
#
# * 4.1: if $m\in\mathbb{Z},n=2m$
#
# $\therefore (x+y)^{2m}=\Sigma_{r=0}^{2m}\frac{(2m)!}{((2m)-r)!*r!}x^{(2m)-r}y^r$
#
# $(x+y)^{2m}=x^{2m}+({2m})x^{{2m}-1}y+...+{2m}xy^{{2m}-1}+y^{2m}$
#
# if $y=-x\implies(x-x)^{2m}=x^{2m}+({2m})x^{{2m}-1}*(-x)+...+{2m}x(-x)^{{2m}-1}+(-x)^{2m}$
#
# According to basic algebra: $(-a)^{2m}=a^{2m}>0,a^{2m}\in\mathbb{R}$
#
# if $y=-x\implies(x-x)^{2m}=x^{2m}-({2m})x^{{2m}}+...+{2m}(-x)^{{2m}}+x^{2m}$
#
# $y=-x\implies(x-x)^{2m}=x^{2m}-({2m})x^{{2m}}+...+{2m}x^{{2m}}+x^{2m}$
#
# $y=-x\implies(x-x)^{2m}=2x^{2m}$
#
#
# * 4.2: if $m\in\mathbb{Z},n=2m+1$
#
# $\therefore (x+y)^{2m+1}=\Sigma_{r=0}^{2m+1}\frac{(2m+1)!}{((2m+1)-r)!*r!}x^{(2m+1)-r}y^r$
#
# $(x+y)^{2m}=x^{2m}+({2m})x^{{2m}-1}y+...+{2m}xy^{{2m}-1}+y^{2m}$
#
# $\{y=-x,x\in\mathbb{R},n\in\mathbb{Z},n\geq3,\frac{n}{2}\notin\mathbb{Z}\}$

# %% [markdown]
# reference:
# * https://youtu.be/eoN6coooZ5U
