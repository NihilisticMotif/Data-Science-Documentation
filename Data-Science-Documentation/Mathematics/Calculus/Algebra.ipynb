# %% [markdown]
# #Introduction of Algebra

# %% [markdown]
# ###(1) Inverse Function

# %% [markdown]
# **What is an inverse function?**
#
# Inverse Function is the function that undo the original function
#
# $f^{-1}(f(x))=x$

# %% [markdown]
# **Example No.1: $f^{-1}(x)$ of $f(x)=\frac{5-x}{3x}$**
#
# Given that:
# * $y=\frac{5-x}{3x}$
#
# $\therefore y=\frac{5}{3x}-\frac{x}{3x}$
#
# $y=\frac{5}{3x}-\frac{1}{3}$
#
# $y+\frac{1}{3}-\frac{5}{3x}=0$
#
# $-\frac{5}{3x}=-(y+\frac{1}{3})$
#
# $\frac{5}{3x}=y+\frac{1}{3}$
#
# $\frac{1}{x}=\frac{3}{5}*(y+\frac{1}{3})$
#
# $x=\frac{1}{\frac{3}{5}*(y+\frac{1}{3})}$
#
# $x=\frac{5}{3(y+\frac{1}{3})}$
#
# $x=\frac{5}{3y+1}$
#
# $\therefore f^{-1}(x)=\frac{5}{3y+1}$

# %% [markdown]
# **Property of a function**
# * A function each input ($x$) has only one output ($y,f(x)$)

# %% [markdown]
# **Property of an inverse function**
# * $f^{-1}(f(x))=f(f^{-1}(x))=x$
# * $f^{-1}(x)\neq\frac{1}{f(x)}$
# * Only function that have one input value ($x$) for every output value ($y$ or $f(x)$), have an inverse function.
# * The domain (possible input value) of $f(x)$ is same as the range (possible output value) of $f^{-1}$ and vice versa.

# %% [markdown]
# ![Screen Shot 2023-03-01 at 12.04.26 PM.png](data:image/png;base64,...)

# %% [markdown]
# reference: https://youtu.be/HfACrKJ_Y2w

# %% [markdown]
# ![Screen Shot 2023-03-01 at 12.22.11 PM.png](data:image/png;base64,...)

# %% [markdown]
# In this picture, the green function is not an inverse function of red function because the value of domain of the red function is not equal to the value of range of the green function.

# %% [markdown]
# #Formula

# %% [markdown]
# ###(1)
# * Binomial theorem: $(x+y)^n=\Sigma_{r=0}^n\frac{n!}{(n-r)!*r!}x^{n-r}y^r$
